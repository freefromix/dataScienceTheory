# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data/titanic_train.csv')

# %%
def impu_age(cols):
    Age = cols[0]
    Pclass = cols[1]
    
    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else:
            return 24
    else:
        return Age

df['Age'] = df[['Age', 'Pclass']].apply(impu_age, axis=1)

# %%
df.drop('Cabin', axis=1, inplace=True)

# %%
sex = pd.get_dummies(df['Sex'], drop_first=True)

# %%
sex = pd.get_dummies(df['Sex'], drop_first=True)
df = pd.concat([df, sex], axis=1)
df.drop(['PassengerId', 'Sex', 'Embarked', 'Name', 'Ticket', 'SibSp', 'Parch', 'Fare'], axis=1, inplace=True)
df.drop(['Pclass'], axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Survived', axis=1)
y = df['Survived']

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier(max_depth=3)
dtree.fit(X, y)
# predictions = dtree.predict(X_test)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# from sklearn.metrics import classification_report, confusion_matrix

# %%
# print(confusion_matrix(y_test, predictions))
# print('-----------')
# print(classification_report(y_test, predictions))

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
from sklearn.tree import export_graphviz

import pydot

# %%
features = list(df.columns[1:])
features
# Out:
# ['Age', 'male']

# %%
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data, feature_names=features, rounded=True, filled=True)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph[0].create_png())

# %%
samples0=df
print('samples0', samples0.count())
# Out:
# samples0 Survived    891
# Age         891
# male        891
# dtype: int64

# %%
value0left = df[(df['Survived']==False)]
value0right = df[(df['Survived']==True)]
print([value0left.count()[0], value0right.count()[0]])
# Out:
# [549, 342]

# %%
samplesleft1 = df[df['male']<=0.5]
samplesright1 = df[df['male']>0.5]
print('samples1\t', 'left:', samplesleft1.count()[0], '\tright:', samplesright1.count()[0])
# Out:
# samples1	 left: 314 	right: 577

# %%
value10left = samplesleft1[(samplesleft1['Survived']==False)]
value10right = samplesleft1[(samplesleft1['Survived']==True)]

value11left = samplesright1[(samplesright1['Survived']==False)]
value11right = samplesright1[(samplesright1['Survived']==True)]

print([value10left.count()[0], value10right.count()[0]], "\t", [value11left.count()[0], value11right.count()[0]])
# Out:
# [81, 233] 	 [468, 109]
