# %% [markdown]
# # K Nearest Neighbors

# %% [markdown]
# Course:
# - [k nearest neighbor (kNN): how it works](https://www.youtube.com/watch?v=k_7gMp5wh5A)
# - [k-NN 2: classification and regression](https://www.youtube.com/watch?v=GbhZcvPLbQg)
# - [k-NN 3: how many neighbours?](https://www.youtube.com/watch?v=9ArwwGaoJwc)
# - [k-NN 4: which distance function?](https://www.youtube.com/watch?v=_EEcjn0Uirw)
# - [k-NN 5: resolving ties and missing values](https://www.youtube.com/watch?v=DRIoyIR8pA4)
# - [k-NN 6: Parzen windows and kernels](https://www.youtube.com/watch?v=UPXIdi_aTEg)
# - [k-NN 7: how to make it faster](https://www.youtube.com/watch?v=sCvJ3zo4DUA)
#
# etc.
#
# - [Playlist](https://www.youtube.com/watch?v=gHdbqsDK9YY&list=PLBv09BD7ez_48heon5Az-TsyoXVYOJtDZ)

# %% [markdown]
# ![knn example](img/example_knn1.png)

# %% [markdown]
# **Training algorithm:**
# 1. Store all the data
#
# **Prediction algorithm:**
# - You find the k closest nearing example.
# - You take the class of these k closest examples.
# - You define the voronoi space of this example to the identified class.
#
# The voronoi space is defined by:
# - Zone where the training example is closer than any other training example.

# %% [markdown]
# **Pros:**
# - Very simple
# - Training is trivial
# - Works with any number of classes.
# - Easy to add more data.
# - Few parameters:
#   - K
#   - Distance metrics.
#
# **Cons:**
# - High Prediction Cos (worse for large datasets)
# - Not good with high dimensional data
# - Categorical Features don't work well

# %% [markdown]
# ![K nearest neighbor to know](img/knn_info.png)

# %% [markdown]
# In the classification phase, k is a user-defined constant, and an unlabeled vector (a query or test point) is classified by assigning the label which is most frequent among the k training samples nearest to that query point.
#
# **Be careful!!** If one data is isolated and K = 1. It will define a space for this data and defining boudaries with data from 1 other class.
#
# ![knn example](img/example_knn2.png)
#
# Solution: If you define K = 3 it needs at least 3 identical data class to define a space.

# %% [markdown]
# ![knn example](img/knn_info2.png)

# %% [markdown]
# ## Example

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Classified_Data.csv')

# %%
df.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         PJF       HQE       NXJ  TARGET CLASS
# 0  0.643798  0.879422  1.231409             1
# 1  1.013546  0.621552  1.492702             0
# 2  1.154483  0.957877  1.285597             0
# 3  1.380003  1.522692  1.153093             1
# 4  0.646691  1.463812  1.419167             1

# %% [markdown]
# ## Standardize everything to the same scale

# %% [markdown]
# We don't know what these column names represent.
#
# You just know that you need to use these unknown features in order to predict a target class 1 or 0.
#
# Because the K and classifier predicts the class of a given test observation by identifying the observations that are nearest to it, the scale of the variable matters a lot.
#
# Any variables that are on a large scale will have a much larger effect on the distance between observations and because of this when you're using K Nearest Neighbors as a classifier what you want to do is try to standardize everything to the same scale.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

sns.pairplot(df)

# %%
# fit(): Compute the mean and std to be used for later scaling.
# We compute everything except the target class. 
scaler.fit(df.drop(['TARGET CLASS'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# transform(): Perform standardization by centering and scaling
scaled_features = scaler.transform(df.drop(['TARGET CLASS'], axis=1))

# %%
# df.columns[:-1] --> Everythin except the last column
df_feat = pd.DataFrame(scaled_features, columns = df.columns[:-1])

# %%
df_feat.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0 -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375 -0.798951
# 1 -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706 -1.129797
# 2 -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156  2.599818
# 3  0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220  1.750208
# 4  1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773  0.596782
#
#         PJF       HQE       NXJ
# 0 -1.482368 -0.949719 -0.643314
# 1 -0.202240 -1.828051  0.636759
# 2  0.285707 -0.682494 -0.377850
# 3  1.066491  1.241325 -1.026987
# 4 -1.472352  1.040772  0.276510

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_feat
y = df['TARGET CLASS']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Classifier implementing the k-nearest neighbors vote.
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# $precision = \frac{true\_positives}{true\_positives+false\_positives}$
#
# $recall = \frac{true\_positives}{true\_positives+false\_negatives}$
#
# f1 score: Combining Precision and Recall using harmonic mean.
# Typically, the harmonic mean is appropriate for situations when the average of rates or ratios is desired.
#
# $Harmonic\_mean = \frac{n}{1/x_1 + 1/x_2 + ... + 1/x_n} = \frac{n}{\sum_{i=1}^{n} \frac{1}{x_{i}}}$
#
# $f1\_score = 2*\frac{precision \times{recall}}{precision + recall}$

# %%
print(confusion_matrix(y_test, pred))
print("-----------")
print(classification_report(y_test, pred))
# Out:
# [[165   8]
#  [ 17 140]]
# -----------
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       173
#            1       0.95      0.89      0.92       157
#
#    micro avg       0.92      0.92      0.92       330
#    macro avg       0.93      0.92      0.92       330
# weighted avg       0.93      0.92      0.92       330

# %%
error_rate=[]

for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40), error_rate, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize='10')
plt.title('Error rate vs K value')
plt.xlabel('K')
plt.ylabel('Error rate')
# Out:
# Text(0, 0.5, 'Error rate')

# %%
# Classifier implementing the k-nearest neighborknn.preabss vote.
knn = KNeighborsClassifier(n_neighbors=34)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

print(confusion_matrix(y_test, pred))
print('\n')
print(classification_report(y_test, pred))
# Out:
# [[167   6]
#  [  7 150]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       173
#            1       0.96      0.96      0.96       157
#
#    micro avg       0.96      0.96      0.96       330
#    macro avg       0.96      0.96      0.96       330
# weighted avg       0.96      0.96      0.96       330
